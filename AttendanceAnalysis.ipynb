# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Name': ['Aditi','Rohan','Sneha','Arjun','Meera','Kiran','Nikhil','Priya','Ravi','Tanya'],
    'Roll_No': [101,102,103,104,105,106,107,108,109,110],
    'Maths': [38,30,40,28,35,39,25,40,33,37],
    'Physics': [40,32,40,30,37,38,27,39,35,38],
    'Chemistry': [37,28,39,25,38,40,26,40,30,35],
    'English': [39,35,40,26,36,37,28,40,34,36],
    'Computer': [40,33,38,29,35,39,25,40,32,37]
}

df = pd.DataFrame(data)
df.to_csv('attendance.csv', index=False)
print("✅ Dataset Created: attendance.csv\n")
display(df)

TOTAL_CLASSES = 40
df['Total_Attended'] = df[['Maths','Physics','Chemistry','English','Computer']].sum(axis=1)
df['Total_Classes'] = TOTAL_CLASSES * 5
df['Attendance_%'] = (df['Total_Attended'] / df['Total_Classes']) * 100
df['Status'] = np.where(df['Attendance_%'] >= 75, 'Regular', 'Irregular')

subject_avg = (df[['Maths','Physics','Chemistry','English','Computer']].mean() / TOTAL_CLASSES) * 100

print("===== Student Attendance Summary =====\n")
display(df[['Name','Roll_No','Attendance_%','Status']])

print("\n===== Subject-wise Average Attendance (%) =====\n")
display(subject_avg)

plt.figure(figsize=(10,6))
plt.bar(df['Name'], df['Attendance_%'], color='skyblue')
plt.title('Overall Attendance Percentage per Student')
plt.xlabel('Student')
plt.ylabel('Attendance (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,5))
subject_avg.plot(kind='bar', color='lightgreen')
plt.title('Average Attendance per Subject')
plt.xlabel('Subjects')
plt.ylabel('Attendance (%)')
plt.tight_layout()
plt.show()

status_counts = df['Status'].value_counts()
plt.figure(figsize=(5,5))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90, colors=['#7FE9DE','#F5B7B1'])
plt.title('Regular vs Irregular Students')
plt.tight_layout()
plt.show()

df.to_csv('attendance_report.csv', index=False)
print("📁 Report saved as 'attendance_report.csv'")

from google.colab import files
files.download('attendance_report.csv')
# Out:
# ✅ Dataset Created: attendance.csv
#      Name  Roll_No  Maths  Physics  Chemistry  English  Computer
# 0   Aditi      101     38       40         37       39        40
# 1   Rohan      102     30       32         28       35        33
# 2   Sneha      103     40       40         39       40        38
# 3   Arjun      104     28       30         25       26        29
# 4   Meera      105     35       37         38       36        35
# 5   Kiran      106     39       38         40       37        39
# 6  Nikhil      107     25       27         26       28        25
# 7   Priya      108     40       39         40       40        40
# 8    Ravi      109     33       35         30       34        32
# 9   Tanya      110     37       38         35       36        37
# ===== Student Attendance Summary =====
#      Name  Roll_No  Attendance_%     Status
# 0   Aditi      101          97.0    Regular
# 1   Rohan      102          79.0    Regular
# 2   Sneha      103          98.5    Regular
# 3   Arjun      104          69.0  Irregular
# 4   Meera      105          90.5    Regular
# 5   Kiran      106          96.5    Regular
# 6  Nikhil      107          65.5  Irregular
# 7   Priya      108          99.5    Regular
# 8    Ravi      109          82.0    Regular
# 9   Tanya      110          91.5    Regular
# ===== Subject-wise Average Attendance (%) =====
# Maths        86.25
# Physics      89.00
# Chemistry    84.50
# English      87.75
# Computer     87.00
# dtype: float64
# 📁 Report saved as 'attendance_report.csv'
